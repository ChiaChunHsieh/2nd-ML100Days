# %% [markdown]
# # 作業
# - 作業目標 : 用 iris (dataset.load_iris()) 資料嘗試跑 hierarchical clustering

# %%
from sklearn import datasets

iris = datasets.load_iris()
X = iris.data
y = iris.target

# %% [markdown]
# 載入 相關套件 並 執行 hierarchical clustering 實驗 ...

# %%
import numpy as np
import matplotlib.pyplot as plt
# Though the following import is not directly being used, it is required
# for 3D projection to work
from mpl_toolkits.mplot3d import Axes3D

from sklearn.cluster import AgglomerativeClustering
from sklearn import datasets

# %%
# fit data
est = AgglomerativeClustering(n_clusters=3, linkage="ward")
est.fit(X)
labels = est.labels_

# plot
fig = plt.figure(figsize=(4, 3))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

ax.scatter(X[:, 0], X[:, 1], X[:, 2],
           c=labels.astype(np.float))

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_title("ward's method")
# Out:
# Text(0.5,0.92,"ward's method")

# %%
# fit data
est = AgglomerativeClustering(n_clusters=3, linkage="single")
est.fit(X)
labels = est.labels_

# plot
fig = plt.figure(figsize=(4, 3))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

ax.scatter(X[:, 0], X[:, 1], X[:, 2],
           c=labels.astype(np.float))

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_title("single linlage")
# Out:
# Text(0.5,0.92,'single linlage')

# %%
# fit data
est = AgglomerativeClustering(n_clusters=3, linkage="complete")
est.fit(X)
labels = est.labels_

# plot
fig = plt.figure(figsize=(4, 3))
ax = Axes3D(fig, rect=[0, 0, .95, 1], elev=48, azim=134)

ax.scatter(X[:, 0], X[:, 1], X[:, 2],
           c=labels.astype(np.float))

ax.w_xaxis.set_ticklabels([])
ax.w_yaxis.set_ticklabels([])
ax.w_zaxis.set_ticklabels([])
ax.set_title("complete linlage")
# Out:
# Text(0.5,0.92,'complete linlage')
